# %%
#install.packages('astsa')
library('astsa')
#astsa - is a applied statistical time-series analysis
help(astsa)

# %%
help(jj)
#Johnson and Johnson Quarterly Earnings Per Share
#Johnson and Johnson quarterly earnings per share, 84 quarters (21 years) measured from the first quarter of 1960 to the last quarter of 1980.

# %%
class(jj) #already a time-series data
plot(jj,main='Johnson and Johnson Quarterly Earnings 1960-1981',xlab='time',ylab='earnings')
# Out:
# [1] "ts"
# Plot with title "Johnson and Johnson Quarterly Earnings 1960-1981"

# %% [markdown]
# #### Quick observations from the above plot
#         1. There is an increasing trend for sure
#         2. Also it has seasonal variations over the trend
#         3. These variations are little in the first ten years but variations are very large in the second half
#         4. So it violates the so-called 'Stationarity'

# %%
help(flu)
#Monthly pneumonia and influenza deaths in the U.S., 1968 to 1978.
#Monthly pneumonia and influenza deaths per 10,000 people in the United States for 11 years, 1968 to 1978.
length(flu)
class(flu)
# Out:
# [1] 132
# [1] "ts"

# %%
plot(flu,main='Monthly pneumonia deaths in the U.S., 1968 to 1978',xlab='time',ylab='deaths')
# Out:
# Plot with title "Monthly pneumonia deaths in the U.S., 1968 to 1978"

# %% [markdown]
# ### In a (weak) stationary time series, there is no
#             1. Systematic change in mean (no trend)
#             2. Systematic change in variance
#             3. Periodic variations
